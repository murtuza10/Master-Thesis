# %%
import os
import sys
# sys.path.append(os.path.abspath(os.path.dirname(__file__)))  # ensures current directory is included
sys.path.append("/home/s27mhusa_hpc/Master-Thesis/XMI_Files")
import spacy
from collections import Counter
import json
input_label_dir = "/home/s27mhusa_hpc/Master-Thesis/Dataset19September/Test_BIO_labels_English_Specific_sentence"
input_token_dir = "/home/s27mhusa_hpc/Master-Thesis/Dataset19September/Test_BIO_tokens_English_Specific_sentence"

# %%
input_label_dir = "/home/s27mhusa_hpc/Master-Thesis/Dataset19September/Train_BIO_labels_English_Specific_sentence"
input_token_dir = "/home/s27mhusa_hpc/Master-Thesis/Dataset19September/Train_BIO_tokens_English_Specific_sentence"


city_list_path = "/home/s27mhusa_hpc/Master-Thesis/de_cities_list.json"
region_list_path = "/home/s27mhusa_hpc/Master-Thesis/de_regions_list.json"
country_list_path = "/home/s27mhusa_hpc/Master-Thesis/countries_list.json"

# Load the list of cities (lowercased for consistent comparison)
with open(city_list_path, "r", encoding="utf-8") as f:
    city_list = set(city.lower() for city in json.load(f))

with open(region_list_path, "r", encoding="utf-8") as f:
    region_list = set(region.lower() for region in json.load(f))

with open(country_list_path, "r", encoding="utf-8") as f:
    country_list = set(country.lower() for country in json.load(f))

all_labels = []


for filename in os.listdir(input_label_dir):
    label_path = os.path.join(input_label_dir, filename)
    with open(label_path, "r", encoding="utf-8") as file:
        content = file.read()
    labels = eval(content)
    
    # labels = eval(content)  # list of BIO labels
    token_path = os.path.join(input_token_dir, f"tokens_{filename}")
    with open(token_path, "r", encoding="utf-8") as file:
        content = file.read()
    tokens = eval(content)

    i = 0
    while i < len(labels):
        label = labels[i]

        # Handle Location entities
        if label == "B-Location":
            entity_tokens = [i]
            j = i + 1
            while j < len(labels) and labels[j] == "I-Location":
                entity_tokens.append(j)
                j += 1
            entity_text = " ".join(tokens[k] for k in entity_tokens)
            
            # Check if entity is a known city
            if entity_text.lower() in city_list:
                labels[i] = "B-city"
                for k in entity_tokens[1:]:
                    labels[k] = "I-city"
            elif entity_text.lower() in region_list:
                labels[i] = "B-region"
                for k in entity_tokens[1:]:
                    labels[k] = "I-region"
            elif entity_text.lower() in country_list:
                labels[i] = "B-country"
                for k in entity_tokens[1:]:
                    labels[k] = "I-country"
            else:
                # If not found in any list, change as O
                labels[i] = "O"
                for k in entity_tokens[1:]:
                    labels[k] = "O"
            i = j
        else:
            i += 1
        


    # all_labels.extend(labels)
    with open(label_path, "w", encoding="utf-8") as file:
        file.write(str(labels))

# %%
from collections import Counter


all_labels = []
b_location_examples = []  # Store (label, token) pairs for B-locationName

for filename in os.listdir(input_label_dir):
    label_path = os.path.join(input_label_dir, filename)
    with open(label_path, "r", encoding="utf-8") as file:
        content = file.read()
    labels = eval(content)
    
    token_path = os.path.join(input_token_dir, f"tokens_{filename}")
    with open(token_path, "r", encoding="utf-8") as file:
        token_content = file.read()
    tokens = eval(token_content)

    # Extend for overall count
    all_labels.extend(labels)

    # Collect B-locationName examples
    for label, token in zip(labels, tokens):
        if label == "I-cropSpecies":
            b_location_examples.append((label, token))
            print(filename)

# Count only B- labels and strip B-
b_counts = Counter(label[2:] for label in all_labels if label.startswith("B-"))

# Print label counts
print("📊 B-Label Counts:")
for label, count in b_counts.items():
    print(f"{label}: {count}")

# Print all B-locationName examples
print("\n📍 Tokens with B-Soil:")
for label, token in b_location_examples:
    print(f"{label}: {token}")
# Out:
# 733796ed-d2b2-4559-8793-62dfbee84002_sentence_004.txt
# 733796ed-d2b2-4559-8793-62dfbee84002_sentence_004.txt
# 41699_sentence_002.txt
# 89235_sentence_001.txt
# 1aa6a96b-f614-4578-ac1b-7a904079d132_sentence_006.txt
# 1aa6a96b-f614-4578-ac1b-7a904079d132_sentence_006.txt
# 1aa6a96b-f614-4578-ac1b-7a904079d132_sentence_006.txt
# 1aa6a96b-f614-4578-ac1b-7a904079d132_sentence_006.txt
# 79228_sentence_006.txt
# 79228_sentence_006.txt
# 79228_sentence_006.txt
# 79228_sentence_006.txt
# 64311_sentence_012.txt
# 79228_sentence_001.txt
# 83691_sentence_013.txt
# 83691_sentence_013.txt
# 77497_sentence_001.txt
# 72566_sentence_004.txt
# 72566_sentence_004.txt
# 82374_sentence_003.txt
# 86332_sentence_019.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_010.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_010.txt
# 66782_sentence_011.txt
# 98507_sentence_001.txt
# 86332_sentence_001.txt
# 86332_sentence_001.txt
# 86332_sentence_001.txt
# 86332_sentence_001.txt
# 85931_sentence_003.txt
# 85931_sentence_004.txt
# 64311_sentence_003.txt
# 83691_sentence_005.txt
# 83691_sentence_005.txt
# 83691_sentence_005.txt
# 64311_sentence_004.txt
# 94467_sentence_017.txt
# 41699_sentence_013.txt
# 41699_sentence_013.txt
# 66782_sentence_001.txt
# 66782_sentence_001.txt
# 66782_sentence_001.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_011.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_011.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_011.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_011.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_011.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_011.txt
# 5e0ffb95-6283-45f4-b1da-806d44d916bf_sentence_005.txt
# 82374_sentence_002.txt
# 82374_sentence_002.txt
# 82374_sentence_002.txt
# 82374_sentence_002.txt
# 82374_sentence_002.txt
# 72566_sentence_005.txt
# 64311_sentence_021.txt
# 8f23ee30-8f84-481a-9a47-9eb6c65af3c4_sentence_004.txt
# 72566_sentence_002.txt
# 85931_sentence_021.txt
# 83691_sentence_012.txt
# 79228_sentence_007.txt
# 92714_sentence_001.txt
# 92714_sentence_001.txt
# 92714_sentence_001.txt
# 92714_sentence_001.txt
# 83691_sentence_004.txt
# 83691_sentence_004.txt
# 64311_sentence_005.txt
# 86332_sentence_007.txt
# 85931_sentence_005.txt
# 42384_sentence_001.txt
# 86332_sentence_009.txt
# 86332_sentence_009.txt
# 66782_sentence_010.txt
# 83691_sentence_009.txt
# dc115e5b-b27a-494b-9054-21ecdbda8d9f_sentence_004.txt
# dc115e5b-b27a-494b-9054-21ecdbda8d9f_sentence_004.txt
# 64311_sentence_008.txt
# 41699_sentence_011.txt
# 64311_sentence_001.txt
# 64311_sentence_001.txt
# 83691_sentence_007.txt
# 83691_sentence_007.txt
# 64311_sentence_006.txt
# 85931_sentence_001.txt
# 85931_sentence_001.txt
# 86332_sentence_004.txt
# 85931_sentence_008.txt
# 00bee634-47e6-490b-89ba-2464c9f09c31_sentence_005.txt
# 00bee634-47e6-490b-89ba-2464c9f09c31_sentence_005.txt
# 00bee634-47e6-490b-89ba-2464c9f09c31_sentence_005.txt
# 00bee634-47e6-490b-89ba-2464c9f09c31_sentence_005.txt
# 82374_sentence_010.txt
# 82374_sentence_001.txt
# 85931_sentence_019.txt
# 72566_sentence_001.txt
# 77497_sentence_004.txt
# 77497_sentence_004.txt
# 77497_sentence_004.txt
# 77497_sentence_004.txt
# 85931_sentence_010.txt
# 64311_sentence_017.txt
# 64311_sentence_010.txt
# 83691_sentence_011.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_027.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_027.txt
# 41699_sentence_007.txt
# 93121_sentence_001.txt
# 64311_sentence_019.txt
# 4bf5ad40-2b1e-47c2-85b5-da2e42335532_sentence_003.txt
# 4bf5ad40-2b1e-47c2-85b5-da2e42335532_sentence_003.txt
# 86332_sentence_005.txt
# ba0e2b40-fb8c-4f50-bb5c-3e8709f733eb_sentence_004.txt
# 85931_sentence_007.txt
# 72566_sentence_011.txt
# 86332_sentence_002.txt
# 86332_sentence_002.txt
# 83691_sentence_006.txt
# 1a52ac80-d78d-4a2a-9e5d-8699ce3b0f00_sentence_020.txt
# 64311_sentence_007.txt
# 83691_sentence_001.txt
# 41699_sentence_006.txt
# 41699_sentence_006.txt
# 70329_sentence_008.txt
# 70329_sentence_008.txt
# 41699_sentence_001.txt
# 41699_sentence_001.txt
# 41699_sentence_001.txt
# 41699_sentence_001.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_028.txt
# 03b52930-0210-4bfc-a4ac-75f7544ce7a5_sentence_028.txt
# 70329_sentence_001.txt
# 70329_sentence_001.txt
# 70329_sentence_001.txt
# 70329_sentence_001.txt
# 92714_sentence_003.txt
# f9cec03d-7fb6-4a99-bbd5-b9913ef92c50_sentence_002.txt
# f9cec03d-7fb6-4a99-bbd5-b9913ef92c50_sentence_002.txt
# 92171_sentence_001.txt
# 72566_sentence_007.txt
# 77497_sentence_005.txt
# 5e0ffb95-6283-45f4-b1da-806d44d916bf_sentence_009.txt
# 85931_sentence_011.txt
# 82374_sentence_009.txt
# 85931_sentence_018.txt
# 85931_sentence_018.txt
# 72566_sentence_009.txt
# 📊 B-Label Counts:
# duration: 95
# city: 84
# region: 164
# country: 137
# soilPH: 120
# startTime: 283
# cropSpecies: 380
# endTime: 99
# soilTexture: 25
# soilOrganicCarbon: 42
# soilAvailableNitrogen: 9
# soilDepth: 20
# cropVariety: 20
# soilReferenceGroup: 11
# longitude: 6
# latitude: 4
# soilBulkDensity: 1
#
# 📍 Tokens with B-Soil:
# I-cropSpecies: vulgare
# I-cropSpecies: L.
# I-cropSpecies: procumbens
# I-cropSpecies: beets
# I-cropSpecies: mays
# I-cropSpecies: aestivum
# I-cropSpecies: vulgare
# I-cropSpecies: napus
# I-cropSpecies: aestivum
# I-cropSpecies: -
# I-cropSpecies: Ae
# I-cropSpecies: .
# I-cropSpecies: cherries
# I-cropSpecies: aestivum
# I-cropSpecies: plant
# I-cropSpecies: plant
# I-cropSpecies: aestivum
# I-cropSpecies: plant
# I-cropSpecies: perfoliatum
# I-cropSpecies: plant
# I-cropSpecies: avium
# I-cropSpecies: oleracea
# I-cropSpecies: L.
# I-cropSpecies: cherry
# I-cropSpecies: communis
# I-cropSpecies: cherry
# I-cropSpecies: Schattenmorelle
# I-cropSpecies: cerasus
# I-cropSpecies: L.
# I-cropSpecies: cherries
# I-cropSpecies: cherries
# I-cropSpecies: cherries
# I-cropSpecies: plant
# I-cropSpecies: perfoliatum
# I-cropSpecies: L.
# I-cropSpecies: cherries
# I-cropSpecies: beet
# I-cropSpecies: procumbens
# I-cropSpecies: webbiana
# I-cropSpecies: cherry
# I-cropSpecies: avium
# I-cropSpecies: L.
# I-cropSpecies: carota
# I-cropSpecies: L.
# I-cropSpecies: sativus
# I-cropSpecies: L.
# I-cropSpecies: graveolens
# I-cropSpecies: L.
# I-cropSpecies: beet
# I-cropSpecies: plant
# I-cropSpecies: perfoliatum
# I-cropSpecies: L.
# I-cropSpecies: mays
# I-cropSpecies: L.
# I-cropSpecies: plant
# I-cropSpecies: cherries
# I-cropSpecies: beet
# I-cropSpecies: mays
# I-cropSpecies: cherries
# I-cropSpecies: plant
# I-cropSpecies: .
# I-cropSpecies: ×
# I-cropSpecies: domestica
# I-cropSpecies: Borkh
# I-cropSpecies: .
# I-cropSpecies: mays
# I-cropSpecies: L.
# I-cropSpecies: cherries
# I-cropSpecies: cherry
# I-cropSpecies: cherry
# I-cropSpecies: mays
# I-cropSpecies: cherry
# I-cropSpecies: cerasus
# I-cropSpecies: trees
# I-cropSpecies: plant
# I-cropSpecies: vulgare
# I-cropSpecies: L.
# I-cropSpecies: cherries
# I-cropSpecies: patellaris
# I-cropSpecies: cherries
# I-cropSpecies: cherry
# I-cropSpecies: plant
# I-cropSpecies: plant
# I-cropSpecies: cherries
# I-cropSpecies: cherries
# I-cropSpecies: cherries
# I-cropSpecies: cherry
# I-cropSpecies: cherries
# I-cropSpecies: mays
# I-cropSpecies: aestivum
# I-cropSpecies: vulgare
# I-cropSpecies: napus
# I-cropSpecies: plant
# I-cropSpecies: perfoliatum
# I-cropSpecies: cherries
# I-cropSpecies: perfoliatum
# I-cropSpecies: aestivum
# I-cropSpecies: -
# I-cropSpecies: Ae
# I-cropSpecies: .
# I-cropSpecies: cherries
# I-cropSpecies: cherries
# I-cropSpecies: cherries
# I-cropSpecies: plant
# I-cropSpecies: sativus
# I-cropSpecies: carota
# I-cropSpecies: webbiana
# I-cropSpecies: beets
# I-cropSpecies: cherries
# I-cropSpecies: hybridum
# I-cropSpecies: multiflorum
# I-cropSpecies: cherry
# I-cropSpecies: aestivum
# I-cropSpecies: cherry
# I-cropSpecies: plant
# I-cropSpecies: cherry
# I-cropSpecies: cerasus
# I-cropSpecies: plant
# I-cropSpecies: sativus
# I-cropSpecies: cherries
# I-cropSpecies: perfoliatum
# I-cropSpecies: patellaris
# I-cropSpecies: procumbens/
# I-cropSpecies: cherry
# I-cropSpecies: fruticosa
# I-cropSpecies: patellaris
# I-cropSpecies: procumbens
# I-cropSpecies: webbiana
# I-cropSpecies: patellaris
# I-cropSpecies: ampeloprasum
# I-cropSpecies: graveolens
# I-cropSpecies: cherry
# I-cropSpecies: fruticosa
# I-cropSpecies: Pall
# I-cropSpecies: .
# I-cropSpecies: ×domestica
# I-cropSpecies: vulgare
# I-cropSpecies: strigosa
# I-cropSpecies: beets
# I-cropSpecies: plant
# I-cropSpecies: .
# I-cropSpecies: beet
# I-cropSpecies: cherries
# I-cropSpecies: plant
# I-cropSpecies: cherries
# I-cropSpecies: cherry
# I-cropSpecies: plant

# %%
location_names = []
filenames = []

for filename in os.listdir(input_label_dir):
    label_path = os.path.join(input_label_dir, filename)
    with open(label_path, "r", encoding="utf-8") as file:
        content = file.read()
    labels = eval(content)

    token_path = os.path.join(input_token_dir, f"tokens_{filename}")
    with open(token_path, "r", encoding="utf-8") as file:
        tokens = eval(file.read())

    i = 0
    while i < len(labels):
        if labels[i] == "B-Soil":
            location_tokens = [tokens[i]]
            i += 1
            while i < len(labels) and labels[i] == "I-Soil":
                location_tokens.append(tokens[i])
                i += 1
            location_names.append(" ".join(location_tokens))
            filenames.append(filename)
        else:
            i += 1

# Print full location names
print("\n📍 Full Location Names:")
for loc in location_names:
    print(loc)
print("\n📍 Full filenames Names:")
for filename in filenames:
    print(filename)
# Out:
# 📍 Full Location Names:
#
# 📍 Full filenames Names:

# %%
import matplotlib.pyplot as plt
# Extract labels and counts
labels = list(b_counts.keys())
counts = list(b_counts.values())

# Create bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, counts, color='skyblue')
plt.title("Label Counts")
plt.xlabel("Labels")
plt.ylabel("Counts")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.xticks(rotation=90)

# Add count labels above bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, yval, ha='center', va='bottom')

plt.tight_layout()
plt.show()
