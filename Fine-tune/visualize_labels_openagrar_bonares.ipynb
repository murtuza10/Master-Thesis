# %%
import os
import sys
import spacy
from collections import Counter
import json

# %%
input_label_dir = "/home/s27mhusa_hpc/Master-Thesis/OpenAgrar_BIO_labels"
input_token_dir = "/home/s27mhusa_hpc/Master-Thesis/OpenAgrar_BIO_tokens"

# %%
import os
from collections import Counter


openagrar_labels = []

for filename in os.listdir(input_label_dir):
    label_path = os.path.join(input_label_dir, filename)
    with open(label_path, "r", encoding="utf-8") as file:
        content = file.read()
    labels = eval(content)
    
    token_path = os.path.join(input_token_dir, f"tokens_{filename}")
    with open(token_path, "r", encoding="utf-8") as file:
        token_content = file.read()
    tokens = eval(token_content)

    # Extend for overall count
    openagrar_labels.extend(labels)


# Count only B- labels and strip B-
b_counts = Counter(label[2:] for label in openagrar_labels if label.startswith("B-"))

# Print label counts
print("📊 B-Label Counts:")
for label, count in b_counts.items():
    print(f"{label}: {count}")
# Out:
# 📊 B-Label Counts:
# startTime: 253
# endTime: 107
# country: 104
# duration: 47
# soilOrganicCarbon: 34
# cropSpecies: 334
# region: 113
# soilDepth: 2
# city: 22
# soilPH: 2
# soilBulkDensity: 2
# longitude: 4
# latitude: 4
# cropVariety: 12
# soilAvailableNitrogen: 11

# %%
import matplotlib.pyplot as plt
# Extract labels and counts
labels = list(b_counts.keys())
counts = list(b_counts.values())

# Create bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, counts, color='skyblue')
plt.title("OpenAgrar Label Counts")
plt.xlabel("Labels")
plt.ylabel("Counts")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.xticks(rotation=90)

# Add count labels above bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, yval, ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
input_label_dir_bonares = "/home/s27mhusa_hpc/Master-Thesis/Bonares_BIO_labels"
input_token_dir_bonares = "/home/s27mhusa_hpc/Master-Thesis/Bonares_BIO_tokens"

# %%
import os
from collections import Counter


bonares_labels = []

for filename in os.listdir(input_label_dir_bonares):
    label_path = os.path.join(input_label_dir_bonares, filename)
    with open(label_path, "r", encoding="utf-8") as file:
        content = file.read()
    labels = eval(content)
    
    token_path = os.path.join(input_token_dir_bonares, f"tokens_{filename}")
    with open(token_path, "r", encoding="utf-8") as file:
        token_content = file.read()
    tokens = eval(token_content)

    # Extend for overall count
    bonares_labels.extend(labels)


# Count only B- labels and strip B-
b_counts = Counter(label[2:] for label in bonares_labels if label.startswith("B-"))

# Print label counts
print("📊 B-Label Counts:")
for label, count in b_counts.items():
    print(f"{label}: {count}")
# Out:
# 📊 B-Label Counts:
# duration: 13
# cropSpecies: 91
# region: 14
# country: 24
# startTime: 36
# endTime: 23
# city: 24
# cropVariety: 14
# soilDepth: 20
# soilTexture: 21
# soilPH: 5
# soilOrganicCarbon: 13
# latitude: 4
# longitude: 4
# soilAvailableNitrogen: 3
# soilBulkDensity: 1

# %%
import matplotlib.pyplot as plt
# Extract labels and counts
labels = list(b_counts.keys())
counts = list(b_counts.values())

# Create bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, counts, color='orange')
plt.title("Bonares Label Counts")
plt.xlabel("Labels")
plt.ylabel("Counts")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.xticks(rotation=90)

# Add count labels above bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, yval, ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Extend for overall count
bonares_labels.extend(openagrar_labels)


# Count only B- labels and strip B-
b_counts = Counter(label[2:] for label in bonares_labels if label.startswith("B-"))

# Print label counts
print("📊 B-Label Counts:")
for label, count in b_counts.items():
    print(f"{label}: {count}")
# Out:
# 📊 B-Label Counts:
# duration: 60
# cropSpecies: 425
# region: 127
# country: 128
# startTime: 289
# endTime: 130
# city: 46
# cropVariety: 26
# soilDepth: 22
# soilTexture: 21
# soilPH: 7
# soilOrganicCarbon: 47
# latitude: 8
# longitude: 8
# soilAvailableNitrogen: 14
# soilBulkDensity: 3

# %%
import matplotlib.pyplot as plt
# Extract labels and counts
labels = list(b_counts.keys())
counts = list(b_counts.values())

# Create bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, counts, color='lightseagreen')
plt.title("Combine Label Counts")
plt.xlabel("Labels")
plt.ylabel("Counts")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.xticks(rotation=90)

# Add count labels above bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, yval, ha='center', va='bottom')

plt.tight_layout()
plt.show()
